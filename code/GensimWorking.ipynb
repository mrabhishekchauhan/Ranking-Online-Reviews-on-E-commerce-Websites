# %%
from keras.preprocessing.text import one_hot
#from keras.preprocessing.text import pad_sequences
from keras.preprocessing.text import text_to_word_sequence
from keras.preprocessing.text import Tokenizer
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense
from keras.models import Model
from keras.layers import Flatten
import numpy
#from keras.utils import plot_model
from keras.layers.embeddings import Embedding
from sklearn.model_selection import cross_val_score
#from sklearn.model_selection import KFold
import pandas as pd
import numpy as np
from numpy import asarray
from numpy import zeros
#from keras.utils.vis_utils import plot_model
from sklearn import metrics
import matplotlib.pyplot as plt
from keras.preprocessing import sequence
from keras.layers import Conv1D, MaxPooling1D
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re
import gensim 
import os
from gensim import models

from gensim.models import Word2Vec


####################preprocessing#######################
stop = set(stopwords.words('english'))
stop=list(stop)
stop_capital=[]
for word in stop:
    stop_capital.append( word.capitalize())
file= open('C:/Users/Abhishek/Dropbox/Summer Project/Data_set/CombinedData_Amazon.csv','r+',encoding="utf8")
list1=file.read()
list1=word_tokenize(list1)
stop_all = stop + stop_capital
filtered = []
for word in list1:
    if word not in stop_all:
        filtered.append(word)
stoplist =set("""M'lady M'lord ma'am Mr. Mrs. Smt. Dr. Er. e.g""".split() )
filtered= [word for word in  filtered if word not in stoplist]
filtered_alphanumeric = []
for word in filtered:
    if(word.isalnum()):
        filtered_alphanumeric.append(word)
final_list_of_words = []
final_list_of_words.append(filtered_alphanumeric)
print(final_list_of_words)


####################Gensim model########################


model = Word2Vec(final_list_of_words,min_count =1 , size = 100 , window=25)
print(model)
model.wv.save_word2vec_format("gensim_model_combined_data.txt", binary=False)
words = list(model.wv.vocab)
model.save("gensim_model_combined_data_model")
gensim_model_combined_data_model = gensim.models.Word2Vec.load("gensim_model_combined_data_model")
vocab = list(model.wv.vocab.keys())
# Out:
# [['Rating', 'Helpfulness', 'Worst', 'product', 'ever', 'bought', 'charging', 'phone', 'suddenly', 'short', 'circuit', 'happened', 'power', 'bank', 'started', 'burn', 'charged', '3', 'times', '4th', 'time', 'burnt', 'good', 'thing', 'apple', 'iphone', '5s', 'got', 'escaped', 'something', 'happened', 'would', 'even', 'worst', 'review', 'burnt', 'powerbank', 'repair', 'replace', 'give', 'want', 'power', 'bank', 'work', 'Ordered', 'Taken', 'Delivery', '6', 'Days', 'Pros', '1', 'bought', 'product', '1000Rs', 'really', 'exceptional', 'value', 'money', 'product2', 'build', 'quality', 'product', 'good', 'seems', 'durable3', 'Charging', 'power', 'seems', 'moderate', 'high', 'better', 'charge', 'powerbank', 'well', 'devices', 'quickly', 'Power', 'Stats', 'Input', 'Power', '5V', 'USB', 'Power', 'USB', 'Type', 'sockets', 'power', 'output', 'Socket', '1', '5W', '5V', '1A', 'Socket', '2', '5V', 'Socket', '3', '5V', 'honest', 'charging', 'power', 'surely', 'gon', 'na', 'drop', 'charge', '3', 'devices', 'simultaneously', 'charge', 'device', 'faster', 'try', 'charge', 'single', 'device', 'use', '5V', 'Cons', '1', 'Lack', 'USB', 'C', 'port', 'almost', '2016', 'flagship', 'devices', 'well', 'new', 'devices', 'conforming', 'futuristic', 'USB', 'C', 'Charging', 'power', 'could', 'better', '15W', '20W', 'input', 'power', 'Charging', 'Time', 'practical', 'time', 'may', 'vary', 'slightly', 'vary', '5', '10', 'Simple', 'version', 'CHARGING', 'TIME', 'charge', '2500', 'mAh', 'Wh', 'smartphone', '0', '100', 'port', 'takes', 'hours', 'Wh', '5W', 'port', 'takes', 'around', '1', 'hour', '10', 'mins', 'Wh', 'POWERBANK', 'CHARGING', 'TIME', 'Time', 'taken', 'charge', 'Power', 'bank', '0', '100', '5', 'hours', '15', 'mins', '55', 'Wh', 'W', 'version', 'CHARGING', 'TIME', 'charge', 'using', 'port', 'Using', '5W', 'Power', 'port', '1hr', 'charge', 'battery', '5Wh', 'Energy', 'port', 'Using', 'Power', 'port', '1hr', 'charge', 'battery', 'Energy', 'words', 'X', 'Watt', 'charging', '1', 'hour', 'called', 'X', 'Wh', 'Watt', 'hour', 'X', 'number', 'Example', 'phone', 'battery', 'energy', 'mAh', 'Ah', 'WhComing', 'point', 'rough', 'time', 'taken', 'charge', 'device', 'charge', 'phone', '2500', 'mAh', 'Wh', 'port', 'takes', 'hours', 'Wh', '5W', 'port', 'takes', 'around', '1', 'hour', '10', 'mins', 'Wh', 'POWERBANK', 'CHARGING', 'TIME', 'Energy', 'Powerbank', 'mAh', '11', 'Ah', '55', 'WhPowerbank', 'input', 'power', 'micro', 'USB', '5V', 'Charging', 'Powerbank', 'one', 'hours', 'gives', 'Wh', 'Energy', 'Powerbank', 'time', 'taken', 'charge', 'Power', 'bank', '0', '100', '5', 'hours', '15', 'mins', '55', 'Wh', 'Wh', 'Additional', 'information', 'V', 'Ah', 'units', 'improper', 'units', 'denoting', 'power', 'Watts', 'W', 'would', 'easier', 'universal', 'unit', 'Power', 'Energy', 'Ah', 'mAh', 'misleading', 'unit', 'Voltage', 'mostly', 'kept', '5V', 'mobile', 'devices', 'constant', 'Energy', 'Wh', 'proper', 'universal', 'unit', 'words', 'use', 'W', 'Power', 'Wh', 'V', 'A10W', '5V', 'mAh', '11', 'Ah', '11', 'Ah', '5V', '55', 'WhTo', 'remember', 'easier', 'suppose', '5V', 'kept', 'constant', 'considering', 'mobile', 'Ah', '5', 'WhMy', 'Nexus', '6P', 'battery', 'storage', 'energy', 'around', 'mAh', 'Ah', 'WhAnd', 'Nexus', '6P', 'wall', 'charging', 'adapter', 'output', 'power', 'rated', '15W', '5V', '3A', 'Please', 'provide', 'Thumbs', 'got', 'info', 'review', 'Dont', 'buy', 'facing', 'problems', 'receives', 'used', 'product', 'Full', 'heating', 'problem', 'Dont', 'charge', 'dont', 'gives', 'power', 'devices', 'dont', 'led', 'lights', 'look', 'like', 'opened', 'screches', 'edges', 'vaste', 'money', 'please', 'choose', 'worst', 'product', 'received', 'stopped', 'working', '20', 'days', 'frankly', 'much', 'expectations', 'powerbank', 'price', 'point', 'charges', 'portable', 'devices', 'fast', 'takes', 'sweet', 'time', 'recharge', 'leave', 'overnight', 'travel', 'anywhere', 'next', 'day', 'recharge', 'iPhone', '6S', 'around', '10', 'percent', 'full', 'twice', 'AND', 'iPad', '4', ' ...
# Word2Vec(vocab=17224, size=100, alpha=0.025)
